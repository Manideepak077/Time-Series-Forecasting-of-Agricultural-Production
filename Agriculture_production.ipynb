# %% [markdown]
# # **Time-Series Forecasting of Agricultural Production**
#
#
# The project aims to forecast agricultural production using historical time-series data obtained from the food Agriculture organisation corpotate statistical Database (FAOSTAT) maintained by the Food and Agriculture Organization (FAO) of the United Nations.

# %% [markdown]
# 1. Import Required Libraries:

# %%
import pandas as pd # this data frame used for reading, filtering, and reshaping tabular data
import numpy as np # numerical operations
import matplotlib.pyplot as plt # used for plotting the time series
import matplotlib.ticker as ticker
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %% [markdown]
# 2. Loading the FAOSTAT Dataset

# %%
# storing the location of your CSV file
file_path = "Production_Crops_Livestock_E_All_Data.csv"
df = pd.read_csv(file_path)
print(df.shape)
df.head()
# Out:
# /tmp/ipykernel_944/3755963969.py:3: DtypeWarning: Columns (11,14,17,20,23,26,29,32,35,38,41,44,47,50,53,56,59,62,65,68,71,74,77,80,83,86,89,92,95,98,101,104,107,110,113,116,119,122,125,128,131,134,137,140,143,146,149,152,155,158,161,164,167,170,173,176,179,182,185,188,191,194,197,200) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# (78974, 201)
#    Area Code Area Code (M49)         Area  Item Code Item Code (CPC)  \
# 0          2            '004  Afghanistan        221          '01371
# 1          2            '004  Afghanistan        221          '01371
# 2          2            '004  Afghanistan        221          '01371
# 3          2            '004  Afghanistan        711          '01654
# 4          2            '004  Afghanistan        711          '01654
#
#                                                 Item  Element Code  \
# 0                                  Almonds, in shell          5312
# 1                                  Almonds, in shell          5412
# 2                                  Almonds, in shell          5510
# 3  Anise, badian, coriander, cumin, caraway, fenn...          5312
# 4  Anise, badian, coriander, cumin, caraway, fenn...          5412
#
#           Element   Unit  Y1961  ... Y2021N    Y2022  Y2022F Y2022N    Y2023  \
# 0  Area harvested     ha    0.0  ...    NaN  36462.0       A    NaN  37000.0
# 1           Yield  kg/ha    NaN  ...    NaN   1742.0       A    NaN   1810.8
# 2      Production      t    0.0  ...    NaN  63515.0       A    NaN  67000.0
# 3  Area harvested     ha    NaN  ...    NaN  25403.0       E    NaN  25439.0
# 4           Yield  kg/ha    NaN  ...    NaN    704.0       E    NaN    704.0
#
#    Y2023F Y2023N     Y2024  Y2024F Y2024N
# 0       A    NaN  39794.00       I    NaN
# 1       A    NaN   1741.90       E    NaN
# 2       A    NaN  69315.64       I    NaN
# 3       E    NaN  25400.00       E    NaN
# 4       E    NaN    704.30       E    NaN
#
# [5 rows x 201 columns]

# %% [markdown]
# 3. Filter Dataset
#
# I select:
#
# 	One country: india
# 	One crop: wheat
# 	Production values only

# %%
#countries = ["India","United Kindom","United States of America"]
country = "India"
crop = "Wheat"
df_filtered = df[
    (df["Area"] == country) &
    #(df["Area"].isin(countries))&
    (df["Item"] == crop) &
    (df["Element"] == "Production")]
df_filtered.head()
# Out:
#        Area Code Area Code (M49)   Area  Item Code Item Code (CPC)   Item  \
# 25786        100            '356  India         15           '0111  Wheat
#
#        Element Code     Element Unit       Y1961  ... Y2021N        Y2022  \
# 25786          5510  Production    t  10997000.0  ...    NaN  107742070.0
#
#        Y2022F Y2022N         Y2023  Y2023F Y2023N        Y2024  Y2024F Y2024N
# 25786       A    NaN  1.105537e+08       A    NaN  113292368.0       A    NaN
#
# [1 rows x 201 columns]

# %%
Unit = df_filtered["Unit"].iloc[0]

# %% [markdown]
# 4. Data Cleaning

# %%
year_columns = [col for col in df_filtered.columns if col.startswith("Y")]
ts = df_filtered[year_columns].T
ts.index = [int(''.join(filter(str.isdigit, year))) for year in year_columns]
ts.columns = ["Production"]
ts.head()
# Out:
#       Production
# 1961  10997000.0
# 1961           A
# 1961         NaN
# 1962  12072000.0
# 1962           A

# %% [markdown]
# Converting to Time Series Format

# %%
# The 'Year' column has already been converted to a datetime index in the previous step.
# Therefore, the following two lines are redundant and cause a KeyError.
ts["Production"] = pd.to_numeric(ts["Production"],errors="coerce")

# Removing missing values
ts = ts.dropna()

# Removing zero or negative values
ts = ts[ts["Production"] > 0]

# Converting to datetime
ts.index = pd.to_datetime(ts.index, format="%Y")

# Sorting chronologically
ts = ts.sort_index()
print("Cleaned Data Preview:")
print(ts.head())
print("Total Observations:", len(ts))
# Out:
# Cleaned Data Preview:
#             Production
# 1961-01-01  10997000.0
# 1962-01-01  12072000.0
# 1963-01-01  10776000.0
# 1964-01-01   9853000.0
# 1965-01-01  12257000.0
# Total Observations: 64

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
# plotting the EDA
ts["Production_Million"] = ts["Production"]/1000000
plt.figure()
plt.plot(ts.index, ts["Production_Million"])
plt.title("Agricultural Production (Metric Tonnes)")
plt.xlabel("Year")
plt.ylabel("Production Metric Tonnes")
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# Training and Testing data

# %%
#Training-testing(80% train, 20% test)
#Spliting the data into 80% training and 20% testing
train_size = int(len(ts) * 0.8)
train = ts.iloc[:train_size]
test = ts.iloc[train_size:]
print("Train size:", len(train))
print("Test size:", len(test))
# Out:
# Train size: 51
# Test size: 13

# %% [markdown]
# Baseline model/ Naïve forecasting:

# %%
#Naïve forecasting/ baseline forcating
#Taking last value from training data
#Repeating it for length of test period
baseline_forecast = np.repeat(train["Production"].iloc[-1],len(test))

#Storing the results in DataFrame
baseline_df = pd.DataFrame({
    "Actual": test["Production"],
    "Baseline Forecast": baseline_forecast}, index=test.index)

# %% [markdown]
# **Ploting Basline model:**

# %%
# plotting the Training, Actual, and Baseline /Naïve Forecasting
plt.figure()
plt.plot(train.index, train["Production"] / 1000000, label="Training Data")
plt.plot(test.index, test["Production"] / 1000000, label="Actual (Test)")
plt.plot(test.index, baseline_forecast/ 1000000, label="Naïve Forecast",linestyle="--")
plt.title("Agricultural Production: Training vs Naïve Forecast")
plt.xlabel("Year")
plt.ylabel("Production (Millions of Metric Tonnes)")
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.grid(True, linestyle='--')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# plotting the Naïve forecasting
plt.figure()
plt.plot(baseline_df.index, baseline_df["Actual"] / 1000000, label="Actual")
plt.plot(baseline_df.index, baseline_df["Baseline Forecast"] / 1000000, label="Naïve Forecast")
plt.title("Agricultural Production: Naïve Forecast vs Actual")
plt.xlabel("Year")
plt.ylabel("Production (Millions of Metric Tonnes)")
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# AutoRegressive intergrated Moving Average (ARIMA) Model:

# %%
#ADF Test: its Augmented Dickey–Fuller (ADF) test is used in time-series analysis to
#checking whether the data is stationary. Stationarity is important because models like
#ARIMA require the time series to have a constant mean and variance over time.
result = adfuller(ts["Production"])
print("ADF Statistic:", result[0])
print("p-value:", result[1])

ts_diff = ts["Production"].diff().dropna()
result_diff = adfuller(ts_diff)
print("ADF Statistic after differencing:", result_diff[0])
print("p-value after differencing:", result_diff[1])
# Out:
# ADF Statistic: 0.5223189974863071
# p-value: 0.9855359074951656
# ADF Statistic after differencing: -11.270068162289286
# p-value after differencing: 1.5447308923906597e-20

# %% [markdown]
# 1. ACF (Autocorrelation Function)
#
# 2. PACF (Partial Autocorrelation Function)

# %%
# ACF and PACF Plotings
#These plots to decide p and q
plt.figure(figsize=(10,4))
plot_acf(ts_diff, lags=20)
plt.show()

plt.figure(figsize=(10,4))
plot_pacf(ts_diff, lags=20)
plt.show()

# %%
model = ARIMA(train["Production"], order=(1,1,0))
model_fit = model.fit()
forecast = model_fit.forecast(steps=len(test))
forecast_million = forecast / 1_000_000
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# ARIMA Model Plotting and ACTUAL Plotting:

# %%
plt.figure(figsize=(12,6))

plt.plot(train.index, train["Production_Million"], label="Train")
plt.plot(test.index, test["Production_Million"], label="Actual")
plt.plot(test.index, forecast_million, label="ARIMA Forecast")

plt.title("ARIMA Forecast vs Actual Production")
plt.xlabel("Year")
plt.ylabel("Production (Million Tonnes)")

plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Long Short Term Memory(LSTM)

# %%
# The data were normalised using a MinMaxScaler to ensure stable training
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train[["Production"]])
test_scaled = scaler.transform(test[["Production"]])

# %%
def create_dataset(data, time_step=3):
    X = []
    y = []
    for i in range(len(data)-time_step):
        X.append(data[i:(i+time_step),0])
        y.append(data[i+time_step,0])
    return np.array(X), np.array(y)

# %%
# comparing the previous years
time_step = 3
X_train, y_train = create_dataset(train_scaled, time_step)
X_test, y_test = create_dataset(test_scaled, time_step)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model_lstm = Sequential()
model_lstm.add(LSTM(50, activation='relu', input_shape=(0,1)))
model_lstm.add(Dense(1))
model_lstm.compile(optimizer='adam', loss='mse')
model_lstm.fit(X_train, y_train, epochs=50, verbose=1)
predictions = model_lstm.predict(X_test)
predictions = scaler.inverse_transform(predictions)
pred_million = predictions.flatten() / 1_000_000
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.2772
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2659
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2565
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2474
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2377
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2284
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2188
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2096
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1998
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1902
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1801
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1698
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1593
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1493
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1384
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1281
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1179
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1076
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0973
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0875
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0776
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0684
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0600
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0516
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0441
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0372
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0313
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0259
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0224
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0196
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0174
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0160
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0153
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0148
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0145
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0142
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0136
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0129
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0122
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0114
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0106
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0100
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0094
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0089
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0084
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0078
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0074
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0068
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0063
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0059
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step

# %%
# Converting actual test values
y_test_actual = scaler.inverse_transform(y_test.reshape(-1,1))
actual_million = y_test_actual.flatten() / 1_000_000

plt.figure(figsize=(10,5))

plt.plot(actual_million, label="Actual Production", marker='o')
plt.plot(pred_million, label="LSTM Prediction", marker='s')

plt.title("LSTM Forecast vs Actual Production")
plt.xlabel("Test Years")
plt.ylabel("Production (Million Metric Tons)")

plt.ticklabel_format(style='plain', axis='y')
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
# Getting years matching prediction length
test_years = test.index[-len(y_test):]

# Converting scaled values back to original values
y_test_actual = scaler.inverse_transform(y_test.reshape(-1,1))
actual_million = y_test_actual.flatten() / 1_000_000
plt.figure(figsize=(10,5))
plt.plot(test_years, actual_million, label="Actual Production", marker='o')
plt.plot(test_years, pred_million, label="LSTM Prediction", marker='s')
plt.title("LSTM Forecast vs Actual Production")
plt.xlabel("Year")
plt.ylabel("Production (Million Metric Tons)")
plt.ticklabel_format(style='plain', axis='y')
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
# -------- Baseline --------
baseline_rmse = np.sqrt(mean_squared_error(test["Production"], baseline_forecast))
baseline_mape = np.mean(np.abs((test["Production"] - baseline_forecast) / test["Production"])) * 100
baseline_mae = mean_absolute_error(test["Production"], baseline_forecast)

# -------- ARIMA --------
arima_rmse = np.sqrt(mean_squared_error(test["Production"], forecast))
arima_mape = np.mean(np.abs((test["Production"] - forecast) / test["Production"])) * 100
arima_mae = mean_absolute_error(test["Production"], forecast)

# -------- LSTM --------
actual_lstm = test["Production"].values[:len(predictions)]
lstm_rmse = np.sqrt(mean_squared_error(actual_lstm, predictions))
actual_lstm = test["Production"].values[:len(predictions)]

lstm_mape = np.mean(np.abs((actual_lstm - predictions) / actual_lstm)) * 100
lstm_mae = mean_absolute_error(actual_lstm, predictions)

# -------- Printing Results --------
print("Baseline RMSE:", baseline_rmse)
print("Baseline MAPE:", baseline_mape)
print("Baseline MAE:", baseline_mae)
print()
print("ARIMA RMSE:", arima_rmse)
print("ARIMA MAPE:", arima_mape)
print("ARIMA MAE:", arima_mae)
print()
print("LSTM RMSE:", lstm_rmse)
print("LSTM MAPE:", lstm_mape)
print("LSTM MAE:", lstm_mae)
# Out:
# Baseline RMSE: 16296520.219541792
# Baseline MAPE: 13.570834549223118
# Baseline MAE: 14261314.870000001
#
# ARIMA RMSE: 17197867.650088787
# ARIMA MAPE: 14.536064084660746
# ARIMA MAE: 15238635.41290782
#
# LSTM RMSE: 2912305.75605914
# LSTM MAPE: 8.102163809629031
# LSTM MAE: 2427919.2

# %%
results = pd.DataFrame({

"Model":["Baseline","ARIMA","LSTM"],

"RMSE":[baseline_rmse, arima_rmse, lstm_rmse],
"MAPE":[baseline_mape, arima_mape, lstm_mape],
"MAE":[baseline_mae, arima_mae, lstm_mae]

})

print(results)
# Out:
#       Model          RMSE       MAPE           MAE
# 0  Baseline  1.629652e+07  13.570835  1.426131e+07
# 1     ARIMA  1.719787e+07  14.536064  1.523864e+07
# 2      LSTM  2.912306e+06   8.102164  2.427919e+06

# %%
# Creating results dataframe of Root Mean Square Error
results = pd.DataFrame({
    "Model": ["Baseline", "ARIMA", "LSTM"],
    "RMSE": [baseline_rmse/1000000, arima_rmse/1000000, lstm_rmse/1000000]
})

print(results)

# Plotting
plt.figure(figsize=(8,5))

plt.bar(results["Model"], results["RMSE"])

plt.title("Model Comparison using RMSE")
plt.xlabel("Models")
plt.ylabel("RMSE in Metric Tonnes")

plt.grid()
plt.tight_layout()

plt.show()
# Out:
#       Model       RMSE
# 0  Baseline  16.296520
# 1     ARIMA  17.197868
# 2      LSTM   2.912306

# %%
# Creating results dataframe of Mean Absolute Percentage Error
results = pd.DataFrame({
    "Model": ["Baseline", "ARIMA", "LSTM"],
    "MAPE": [baseline_mape, arima_mape, lstm_mape]
})

print(results)

# Plotting
plt.figure(figsize=(8,5))
plt.bar(results["Model"], results["MAPE"])


plt.title("Model Comparison using MAPE")
plt.xlabel("Models")
plt.ylabel("RMSE in Metric Tonnes")

plt.grid(axis='y')
plt.tight_layout()

plt.show()
# Out:
#       Model       MAPE
# 0  Baseline  13.570835
# 1     ARIMA  14.536064
# 2      LSTM   8.102164

# %%
# Creating results dataframe Mean absolute Error
results = pd.DataFrame({
    "Model": ["Baseline", "ARIMA", "LSTM"],
    "MAE": [baseline_mae/1000000, arima_mae/1000000, lstm_mae/1000000]
})

print(results)

# Plotting
plt.figure(figsize=(8,5))
plt.bar(results["Model"], results["MAE"])

plt.title("Model Comparison using MAE")
plt.xlabel("Models")
plt.ylabel("RMSE in Metric Tonnes")

plt.grid(axis='y')
plt.tight_layout()

plt.show()
# Out:
#       Model        MAE
# 0  Baseline  14.261315
# 1     ARIMA  15.238635
# 2      LSTM   2.427919

# %% [markdown]
# Hyper parameter Tuning

# %%
# Hyperparameter tuning for ARIMA
p_values = [0, 2]
d_values = [0, 1]
q_values = [0, 2]

best_score = float("inf")
best_order = None

for p in p_values:
    for d in d_values:
        for q in q_values:
            try:
                model = ARIMA(train["Production"], order=(p, d, q))
                model_fit = model.fit()

                forecast = model_fit.forecast(steps=len(test))

                # RMSE
                rmse = np.sqrt(mean_squared_error(test["Production"], forecast))

                # MAE
                mae = mean_absolute_error(test["Production"], forecast)

                # MAPE
                mape = np.mean(
                    np.abs((test["Production"] - forecast) / test["Production"])
                ) * 100

                print(f"ARIMA({p},{d},{q}) -> RMSE: {rmse:.3f}, MAE: {mae:.3f}, MAPE: {mape:.3f}%")

                # Using RMSE to selecting best model
                if rmse < best_score:
                    best_score = rmse
                    best_order = (p, d, q)

            except:
                continue

print("\nBest ARIMA Order:", best_order)
print("Best RMSE:", best_score)
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ARIMA(0,0,0) -> RMSE: 56189030.535, MAE: 55619321.989, MAPE: 54.738%
# ARIMA(0,0,2) -> RMSE: 54008794.868, MAE: 52383838.845, MAPE: 51.312%
# ARIMA(0,1,0) -> RMSE: 16296520.220, MAE: 14261314.870, MAPE: 13.571%
# ARIMA(0,1,2) -> RMSE: 16316707.698, MAE: 14343517.725, MAPE: 13.662%
# ARIMA(2,0,0) -> RMSE: 18511098.788, MAE: 16469007.728, MAPE: 15.724%
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# ARIMA(2,0,2) -> RMSE: 18280520.946, MAE: 15972747.648, MAPE: 15.196%
# ARIMA(2,1,0) -> RMSE: 16062637.461, MAE: 14090964.949, MAPE: 13.416%
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency YS-JAN will be used.
#   self._init_dates(dates, freq)
# ARIMA(2,1,2) -> RMSE: 6563629.880, MAE: 6119500.562, MAPE: 5.974%
#
# Best ARIMA Order: (2, 1, 2)
# Best RMSE: 6563629.880238358

# %%
plt.figure()

# Actual vs Forecast
plt.plot(test.index, test["Production"], label="Actual")
plt.plot(forecast.index, forecast, label="ARIMA Forecast")

# Labels
plt.xlabel("Year")
plt.ylabel("Production")
plt.title("ARIMA Forecast vs Actual (Year-wise)")

# Removing scientific notation (millions format)
plt.ticklabel_format(style='plain', axis='y')

plt.legend()
plt.show()

# %%
# Hyperparameter tuning for LSTM
neurons_list = [20, 50, 100]
epochs_list = [20, 50]
batch_sizes = [1, 4]

best_rmse = float("inf")
best_params = None

for neurons in neurons_list:
    for epochs in epochs_list:
        for batch in batch_sizes:

            model = Sequential()
            model.add(LSTM(neurons, input_shape=(time_step,1)))
            model.add(Dense(1))

            model.compile(optimizer='adam', loss='mse')

            model.fit(X_train, y_train, epochs=epochs, batch_size=batch, verbose=0)

            pred = model.predict(X_test)
            pred = scaler.inverse_transform(pred)

            # RMSE
            rmse = np.sqrt(mean_squared_error(y_test_actual, pred))

            # MAE
            mae = mean_absolute_error(y_test_actual, pred)

            # MAPE
            mape = np.mean(
                np.abs((y_test_actual - pred) / y_test_actual)
            ) * 100

            print(f"Neurons:{neurons}, Epochs:{epochs}, Batch:{batch} → RMSE:{rmse:.3f}, MAE:{mae:.3f}, MAPE:{mape:.3f}%")

            if rmse < best_rmse:
                best_rmse = rmse
                best_params = (neurons, epochs, batch)

print("\nBest LSTM Parameters:", best_params)
print("Best RMSE:", best_rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Neurons:20, Epochs:20, Batch:1 → RMSE:5644725.555, MAE:4036927.469, MAPE:4.174%
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Neurons:20, Epochs:20, Batch:4 → RMSE:9314544.455, MAE:8758706.931, MAPE:8.410%
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Neurons:20, Epochs:50, Batch:1 → RMSE:4820742.070, MAE:3974625.731, MAPE:4.042%
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Neurons:20, Epochs:50, Batch:4 → RMSE:5518444.437, MAE:3817683.469, MAPE:3.977%
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Neurons:50, Epochs:20, Batch:1 → RMSE:5013397.145, MAE:4148405.069, MAPE:4.243%
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Neurons:50, Epochs:20, Batch:4 → RMSE:8486923.289, MAE:6807441.069, MAPE:6.820%
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Neurons:50, Epochs:50, Batch:1 → RMSE:4907429.085, MAE:3608849.069, MAPE:3.763%
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Neurons:50, Epochs:50, Batch:4 → RMSE:5915012.086, MAE:4290083.469, MAPE:4.414%
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Neurons:100, Epochs:20, Batch:1 → RMSE:5087609.508, MAE:3643430.669, MAPE:3.806%
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Neurons:100, Epochs:20, Batch:4 → RMSE:6723120.344, MAE:4883207.069, MAPE:4.974%
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Neurons:100, Epochs:50, Batch:1 → RMSE:9433851.092, MAE:8968482.931, MAPE:8.606%
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Neurons:100, Epochs:50, Batch:4 → RMSE:4921789.774, MAE:3995983.469, MAPE:4.107%
#
# Best LSTM Parameters: (20, 50, 1)
# Best RMSE: 4820742.069926249

# %%
y_actual = y_test_actual.flatten()
y_pred = pred.flatten()

min_len = min(len(y_actual), len(y_pred))

y_actual = y_actual[:min_len]
y_pred = y_pred[:min_len]
x_axis = test.index[:min_len]

plt.figure(figsize=(10,5))

plt.plot(x_axis, y_actual, label="Actual")
plt.plot(x_axis, y_pred, label="LSTM Forecast")

plt.xlabel("Year")
plt.ylabel("Production")
plt.title("LSTM Forecast vs Actual")

plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(nbins=6))
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:.0f}'))

plt.legend()
plt.xticks(rotation=45)

plt.show()
